# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import matplotlib.pyplot as plt 

# 한글문제 해결처리 
################################################################
from matplotlib import font_manager, rc
import platform
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

df=pd.read_csv("21.모범음식점현황(사전정보공표181231).csv", encoding='cp949')
df
#1번
# df2=df.groupby(by='업태').size().reset_index(name='건수')
# plt.plot(df2['업태'],df2['건수'])
# plt.show()

#2번
# filter = df['시군구']=='거창군'
# filter2 = df['시군구']=='함양'
# filter3 = filter|filter2
# df2 = df[filter3]

# df3=df.groupby(by='주메뉴').size().reset_index(name='건수')
# df4=df3.sort_values('건수',ascending=False).tail(4)
# plt.plot(df4['주메뉴'],df4['건수'])
# plt.show()

# 3번

filter=df['주메뉴'].str.contains('낙지')
df2 = df[filter]

df3 = df2.groupby(by='주메뉴').size().reset_index(name='건수')
df4 = df3.sort_values(by='건수', ascending= False).head(3)
plt.plot(df4['주메뉴'],df4['건수'])
plt.show()
