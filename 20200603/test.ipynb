# %%
import numpy as np 
import pandas as pd 

data = pd.read_csv("ign_game_reviews.csv")#, header = 0)
data.shape
data.head()
data.tail(2)

data.iloc[0:5,:]
data.iloc[:,:]
data.iloc[:,0]
data.iloc[9,:]
data.iloc[[1,9],:]
df=data.iloc[:,1:]
df.index
df.head()
#5행 score 
df.loc[:5,'score']
df.columns
df.loc[:5,['score','release_year']]
df['score']
type(df['score'])
df['score'].sum()
df['score'].mean()
df.mean()
df.mean(axis=0)
df.mean(axis=1)
df.count()
df.max()
df.describe()
df.corr()#상관관계 
df['score'] / 2
df['score'] > 7
filter = df['score'] > 7 
filter

df2=df[filter]
df.shape
df2.head()
df['platform']
filter2 = (df['score'] > 7 ) & (df['platform'] == 'Xbox 360')
filter2
df3 = df[filter2]
df3.shape
df3.head()
df['score'].plot(kind='hist')

df3['score'].plot(kind='hist')

filter3=df['platform'] == "Xbox 360"
df[filter3]
df[df['platform'] == "Xbox 360"]['score'].plot(kind='hist')
